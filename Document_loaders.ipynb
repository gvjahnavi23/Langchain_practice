# %%
# !pip install langchain_core
# !pip install langchain
# !pip install langchain_community
# !pip install langchain_google_genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from google.colab import userdata
gemini_api = userdata.get('gemini_api')

model = ChatGoogleGenerativeAI(
    model = 'gemini-2.5-flash',
    api_key = gemini_api,
    temperature = 0.2
)

# %%
from langchain_community.document_loaders import TextLoader

text_loader = TextLoader(file_path = '/content/git_local_to_github_guide.txt')

text_content = text_loader.load()
# Out:
# /tmp/ipykernel_16261/1469862149.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
text_content
# Out:
# [Document(metadata={'source': '/content/git_local_to_github_guide.txt'}, page_content='\nGIT GUIDE: LOCAL → GITHUB\n\n1) Create the repo on GitHub (once)\n- Go to github.com/new\n- Repo name: Python-DSA-Codes (match exact casing)\n- If your local already has files, leave all boxes unchecked (no README, no .gitignore, no license).\n- Click Create repository.\n\n2) Initialize & commit locally (if not already)\n    git init\n    git add .\n    git commit -m "Initial commit"\n\n3) Add/Correct the remote URL\n    git remote remove origin 2>NUL || true\n    git remote add origin https://github.com/gvjahnavi23/Python-DSA-Codes.git\n\nVerify:\n    git remote -v\n\n4) Pick your default branch name & push\nIf using main:\n    git branch -M main\n    git push -u origin main\n\nIf using master:\n    git push -u origin master\n\n5) If GitHub has a README (not empty repo)\n    git branch -M main\n    git pull --rebase origin main\n    git push -u origin main\n\n6) Authenticate (first push via HTTP
# ...

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

str_parser = StrOutputParser()
template = PromptTemplate(
    template = 'What is the text is about (give me short description)\n {text}',
    input_variables = ['text']
)

# %%
chain = template | model | str_parser

result = chain.invoke(text_content)
print(result)
# Out:
# This text is a step-by-step guide on how to push a local Git repository to GitHub, covering initial setup, committing, adding a remote URL, pushing to a branch, authentication, and common troubleshooting tips.

# %%
# !pip install pypdf

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_loader = PyPDFLoader('/content/Beginner Llm Engineer Detailed Roadmap With Definitions.pdf')
pdf_content = pdf_loader.load()

# %%
pdf_content
# Out:
# [Document(metadata={'producer': 'WeasyPrint 68.0', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Beginner Llm Engineer Detailed Roadmap With Definitions', 'author': 'ChatGPT Canvas', 'source': '/content/Beginner Llm Engineer Detailed Roadmap With Definitions.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='Beginner to Advanced LLM Engineer Roadmap\nA complete beginner-friendly roadmap for learning Machine Learning, Deep Learning, LLMs, and RAG\nsystems.\nThis roadmap includes:\nTopics\nSubtopics\nDefinitions\nLearning order\nCore concepts\nSTEP 1 — Basic Machine Learning Foundations\nGoal: Understand how AI models learn patterns from data.\nEstimated Time: 1–2 Weeks\n1. Supervised Learning\nDefinition: Learning using labeled data.\nExample: Input: Resume Output: Selected / Rejected\nLearn\nInputs and outputs\nFeatures and labels\nPredictions\nTraining process\nSubtopics\nRegression\nDefinition: Predicting continuous values.\nExample: House price prediction.
# ...

# %%
from langchain_community.document_loaders import WebBaseLoader

web_loader = WebBaseLoader('https://en.wikipedia.org/wiki/LLM')
web_content = web_loader.load()
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
type(web_content)
# Out:
# list

# %%
# !pip install docx2txt

# %%
from annotated_types import doc
from langchain_community.document_loaders import Docx2txtLoader

doc_loader = Docx2txtLoader('/content/JAHNAVI.docx')
doc_content = doc_loader.lazy_load()

# %%
doc_content

# %%
# !!pip install unstructured
# Out:
# ['Requirement already satisfied: unstructured in /usr/local/lib/python3.12/dist-packages (0.22.31)',
#  'Requirement already satisfied: beautifulsoup4<5.0.0,>=4.14.3 in /usr/local/lib/python3.12/dist-packages (from unstructured) (4.14.3)',
#  'Requirement already satisfied: charset-normalizer<4.0.0,>=3.4.4 in /usr/local/lib/python3.12/dist-packages (from unstructured) (3.4.7)',
#  'Requirement already satisfied: emoji<3.0.0,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from unstructured) (2.15.0)',
#  'Requirement already satisfied: filelock<4.0.0,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from unstructured) (3.29.0)',
#  'Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from unstructured) (1.2.0)',
#  'Requirement already satisfied: html5lib<2.0.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from unstructured) (1.1)',
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

directory_loader = DirectoryLoader(
    path='/content/sample_data',
    glob='**/*.csv',
    show_progress=True
)

directory_content = directory_loader.load()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]WARNING:unstructured:No features in text.
# WARNING:unstructured:No features in text.
#  75%|███████▌  | 3/4 [03:25<00:47, 47.07s/it]WARNING:unstructured:No features in text.
# WARNING:unstructured:No features in text.
# 100%|██████████| 4/4 [04:56<00:00, 74.07s/it]

# %%
directory_content
# Out:
# Buffered data was truncated after reaching the output size limit.
